# %% [markdown]
# # Act Report
#
#
# ## Introduction
#
# This is a data analysis project involving the WeRateDogs (@dog_rates) twitter account. I had to gatther 3 different data, assess them, clean them, and produce quality insights and visualizations out of them.
# After the data wrangling process, we shall store the cleaned data in a file. I will go as brief as posible. For the full source code, check out thie [notebook](#).
#
# **In this report, i will be introducing you to:
#
# 1. A brief introduction to the effort that precced my insight
#
# 2. Questions analysed based on my wrangling effort.
#
# 3. My Insights
#
# 4. How i got the insights
#
# 5. Visualizations to back up my insight.

# %% [markdown]
# ## 1. A brief introduction to the effort that precced my insight
#
#
# Before insights can be drawn from any dataset, there are careful processes and procedures that must be considered.
#
# 1. Data Gathering: As stated in the introductory section, i had to gather relevant data from different sources ranging from a simple download of a csv, to the download of a tsv file from Udacity server, and finally using provided materials to gather the third jason file. After all the necessary data were gathered i proceeded to the next step
#
# 2. Assess Data: I assessed the downloaded data visually, and programatically for quality and tidiness issues. This was done by scroling through the datasets, and using functions to summarrise and streamline the data to relevant information.
#
# 3. Cleaning Data: After assessing the gathered data, i had to clean or refine the data so it can be well structured and refined to the quality needed for high quality insights. The result of this is a master dataset which was used for my visualizations and insights.

# %% [markdown]
# ## 2. Questions analysed based on my wrangling effort
#
# - **What is the distribution of the dog stages?**
# - **Which dog stage tends to get higher ratings?**
# - **Does Favorite count (Likes) correlate with Retweets?**

# %% [markdown]
# ## 3. My Insights
#
# **It was oberved that**
# - The pupper dog stage significantly outnumbered other dog stages analysed
# - The pupper dog stage also tends to get higher ratings
# - Retweet_count correlates strongly with favorite_count. This means that dogs with high retweets also tend to get high likes

# %% [markdown]
# ## 4. How i got the insights
#
#
# Based on the cleaned data (master data), i plotted 4 different graphs for visualization, which was what my insight is based on.

# %% [markdown]
# ## 5. Visualizations to back up my insight.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
